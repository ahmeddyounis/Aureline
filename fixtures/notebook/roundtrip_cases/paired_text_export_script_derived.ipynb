# %% [markdown]
# This notebook has a paired .py export. The .py form is DERIVED,
# not canonical; promoting it to canonical source on save is forbidden.

# %%
# Canonical direction: notebook->export_script:v1
