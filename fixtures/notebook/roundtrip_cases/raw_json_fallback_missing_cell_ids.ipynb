# %% [markdown]
# Legacy-format document: cells carry no stable `id` field (pre-nbformat 4.5).
# The diff surface falls back to raw-JSON compare with a visible chip
# `fallback_cell_id_stability_not_available`; cell-aware merge is denied.

# %%
# No stable cell id: raw JSON fallback on compare; structured merge denied.
