# %% [markdown]
# No kernel is resolvable for this notebook: the kernelspec names a
# toolchain that is not installed on this host and no remote-agent session
# is attached. The notebook MUST still open, render, diff, merge, search,
# and export. Only execution-dependent surfaces render the typed chip
# `execution_unavailable_without_kernel`.

# %%
# This cell is editable and reviewable; run affordances render the chip.
