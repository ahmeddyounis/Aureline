# %%
# Kernel name at capture was 'legacy-python-renamed'; no matching kernelspec today.
# Outputs below are orphaned; no kernel session can be bound to them.
# Reopening the notebook must keep the document editable and reviewable.
# Out:
# orphaned-output-placeholder-redacted-ref
